# %% [markdown]
# ## INTRODUCTION TO STREAMLIT
#
# It is an open-source app framework for the Machine Learning and Data Science Projects. It Allows you to create beautiful web Applications for your machine learning and data science projects with simple python scripts.
