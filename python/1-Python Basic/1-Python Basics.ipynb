# %%
# Dynamic Typing
# Python allows the type of a variable to change as the # program executes 

var =10 # int
print(var,type(var))

var = "HEllo" # str
print(var,type(var))


var = 3.14 #float
print(var,type(var))

print("hey ritu")
# Out:
# 10 <class 'int'>
# HEllo <class 'str'>
# 3.14 <class 'float'>
# hey ritu

# %%
# Type Conversion 

age = 25
print(type(age))

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# helo
# 25
# <class 'str'>

# %%
## Multiple statemenent on a single line


x=5; y=100; z=15; a = y+x
print(z)

print(a)
# Out:
# 15
# 105

# %%
## LIne Continuation 

total = 1+2+3+4+5+\
7+8

print(total)
# Out:
# 30
