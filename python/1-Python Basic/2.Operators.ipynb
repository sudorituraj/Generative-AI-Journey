# %%
#Arthiemtic Operation


a=10;b=5

add =  a+b
sub = a-b
multiply =  a* b
div = a/b 
floor_division = a//b # floor division
modulus = a%b # Remainder
exponent = a**b

print("calculator")
print("Add:",add)
print("Sub:",sub)
print("Multiply:",multiply)
print("Div:",div)
print("floor_division:",floor_division)
print("Modulus:", modulus)
print("Exponent:",exponent)
# Out:
# calculator
# Add: 15
# Sub: 5
# Multiply: 50
# Div: 2.0
# floor_division: 2
# Modulus: 0
# Exponent: 100000

# %%
## COMPARISION OPERATPORS
## == (Equal to Operator)


a = 10
b = 10

a==b
# Out:
# True

# %%
## Greater than

num1= 45; num2 = 55
num1>num2
# Out:
# False

# %%
## LEss Than # LEss than or equal to 
num1= 45; num2 = 55
num1<num2
# Out:
# True

# %%
#### LOGICAL OPERATORS
## and  not, or

x = True
y = False

result = x and y 
print(result)


a = False
b = True

result1 = a or b
print(result1)
# Out:
# False
# True

# %%
## not operator -- Reverse of a boolean value
x =  True
not x
# Out:
# False

# %%
#calculator Example 

operation = input("what do you want to perform? \n"
                  "Addition\n"
                  "Substraction\n"
                  "MUltiplication\n"
                  "Divide\n")

num1 = int(input("Enter the first Number: "))
num2 = int(input("Enter the second number: "))

def sum():
    return num1+num2

if operation == "Addition":
    print("here is the sum: ", sum())
else:
    pass

# %%
# Example: Building a Calculator

operation = input(
    "What do you want to perform?\n"
    "add\n"
    "sub\n"
    "multiply\n"
    "divide\n"
)

num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

def sum():
    return num1 + num2

def difference():
    return num1 - num2

def product():
    return num1 * num2

def quotient():
    if num2 != 0:
        return num1 / num2
    else:
        return "Division by zero not allowed"

if operation == "add":
    print("Here is the sum:", sum())

elif operation == "sub":
    print("Here is the difference:", difference())

elif operation == "multiply":
    print("Here is the product:", product())

elif operation == "divide":
    print("Here is the quotient:", quotient())

else:
    print("Invalid operation selected")
# Out:
# Here is the sum: 5
