# %% [markdown]
# #### Example 1. Manage A To Do list
#
#
# * Create a to do list to keep track of the tasks

# %%
to_do_lst= ["Buy Grocery","clean the house","pay bills"]
##Adding tasks

to_do_lst.append("Meet the HR")
to_do_lst.append("Run")
print(to_do_lst)


## Remove the house

to_do_lst.remove("clean the house")
print(to_do_lst)

## Checking if a task is in th lst

if "pay bills" in to_do_lst:
    print("True")
# Out:
# ['Buy Grocery', 'clean the house', 'pay bills', 'Meet the HR', 'Run']
# ['Buy Grocery', 'pay bills', 'Meet the HR', 'Run']
# True
